# %% [markdown]
# # Perky Penguins - Climate Change Data Scraping and Cleaning

# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests
import pymongo
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo
from webdriver_manager.chrome import ChromeDriverManager
import pathlib

# %%
# !pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\grace\anaconda3\lib\site-packages (4.7.3)
# Requirement already satisfied: requests in c:\users\grace\anaconda3\lib\site-packages (from pytrends) (2.24.0)
# Requirement already satisfied: lxml in c:\users\grace\anaconda3\lib\site-packages (from pytrends) (4.6.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\grace\anaconda3\lib\site-packages (from pytrends) (1.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\grace\anaconda3\lib\site-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\grace\anaconda3\lib\site-packages (from requests->pytrends) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\grace\anaconda3\lib\site-packages (from requests->pytrends) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\grace\anaconda3\lib\site-packages (from requests->pytrends) (2020.6.20)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\grace\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\grace\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\grace\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\grace\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)

# %%
from pytrends.request import TrendReq
pytrend = TrendReq()

# %% [markdown]
# ### Import and clean CO2 Emission & Population data from The World Bank. The result will be used for visualization.

# %%
# Name the CO2 Emission CSV file
CO2_emission_file = pathlib.Path('CO2_emissions_per_capita.csv')

# Read and display the CO2 Emission CSV with Pandas
CO2_emission_df = pd.read_csv(CO2_emission_file)

# %%
CO2_emission_df_2 = CO2_emission_df[['Country Name','Country Code', 'Indicator Name', '2006', '2007','2008','2009','2010','2011','2012','2013','2014','2015','2016']]
CO2_emission_df_2
# Out:
#      Country Name Country Code                          Indicator Name  \
# 0           Aruba          ABW  CO2 emissions (metric tons per capita)
# 1     Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2          Angola          AGO  CO2 emissions (metric tons per capita)
# 3         Albania          ALB  CO2 emissions (metric tons per capita)
# 4         Andorra          AND  CO2 emissions (metric tons per capita)
# ..            ...          ...                                     ...
# 259        Kosovo          XKX  CO2 emissions (metric tons per capita)
# 260   Yemen, Rep.          YEM  CO2 emissions (metric tons per capita)
# 261  South Africa          ZAF  CO2 emissions (metric tons per capita)
# 262        Zambia          ZMB  CO2 emissions (metric tons per capita)
# 263      Zimbabwe          ZWE  CO2 emissions (metric tons per capita)
#
#           2006       2007       2008       2009       2010       2011  \
# 0    26.947726  27.895023  26.229553  25.915322  24.670529  24.507516
# 1     0.062428   0.083893   0.151721   0.238399   0.289988   0.406424
# 2     1.105019   1.203134   1.185000   1.234425   1.244092   1.262825
# 3     1.302576   1.322335   1.484311   1.495600   1.578574   1.803715
# 4     6.746052   6.519387   6.427810   6.121580   6.122595   5.867410
# ..         ...        ...        ...        ...        ...        ...
# 259        NaN        NaN   4.266386   4.650695   4.745656   4.672303
# 260   1.030386   0.985390   1.020428   1.090990   1.011975   0.865783
# 261   9.236950   9.498786   9.979458   9.967159   9.173055   9.179457
# 262   0.188267   0.154271   0.168958   0.189800   0.197823   0.208412
# 263   0.859470   0.806649   0.627678   0.447289   0.614549   0.746236
#
#           2012      2013      2014      2015      2016
# 0    13.157722  8.353561  8.410064  8.610374  8.426911
# 1     0.345149  0.280455  0.253728  0.262556  0.245101
# 2     1.361181  1.295075  1.664741  1.240245  1.202861
# 3     1.697966  1.697279  1.900070  1.602648  1.577163
# 4     5.916884  5.901775  5.832906  5.969786  6.072370
# ..         ...       ...       ...       ...       ...
# 259   4.395272  4.441262  4.005283  4.702186  5.031520
# 260   0.764021  1.013754  0.955251  0.497091  0.390480
# 261   8.794997  8.553336  8.882322  8.376655  8.480658
# 262   0.254267  0.265078  0.292412  0.285428  0.314183
# 263   0.600303  0.881705  0.891739  0.891624  0.782777
#
# [264 rows x 14 columns]

# %%
# Name the population CSV file
population_file = pathlib.Path('population_total_by_country.csv')

# Read and display the population CSV with Pandas
population_df = pd.read_csv(population_file)

# %%
population_df_2 = population_df[['Country Name', 'Country Code', 'Indicator Name', '2006', '2007','2008','2009','2010','2011','2012','2013','2014','2015','2016']]
population_df_2
# Out:
#      Country Name Country Code     Indicator Name        2006        2007  \
# 0           Aruba          ABW  Population, total    100834.0    101222.0
# 1     Afghanistan          AFG  Population, total  26433049.0  27100536.0
# 2          Angola          AGO  Population, total  20149901.0  20905363.0
# 3         Albania          ALB  Population, total   2992547.0   2970017.0
# 4         Andorra          AND  Population, total     80993.0     82684.0
# ..            ...          ...                ...         ...         ...
# 259        Kosovo          XKX  Population, total   1719536.0   1733404.0
# 260   Yemen, Rep.          YEM  Population, total  20687646.0  21282515.0
# 261  South Africa          ZAF  Population, total  48489459.0  49119759.0
# 262        Zambia          ZMB  Population, total  12173514.0  12502958.0
# 263      Zimbabwe          ZWE  Population, total  12155491.0  12255922.0
#
#            2008        2009        2010        2011        2012        2013  \
# 0      101358.0    101455.0    101669.0    102046.0    102560.0    103159.0
# 1    27722276.0  28394813.0  29185507.0  30117413.0  31161376.0  32269589.0
# 2    21695634.0  22514281.0  23356246.0  24220661.0  25107931.0  26015780.0
# 3     2947314.0   2927519.0   2913021.0   2905195.0   2900401.0   2895092.0
# 4       83862.0     84463.0     84449.0     83747.0     82427.0     80774.0
# ..          ...         ...         ...         ...         ...         ...
# 259   1747383.0   1761474.0   1775680.0   1791000.0   1807106.0   1818117.0
# 260  21892146.0  22516460.0  23154855.0  23807588.0  24473178.0  25147109.0
# 261  49779471.0  50477011.0  51216964.0  52004172.0  52834005.0  53689236.0
# 262  12848530.0  13215139.0  13605984.0  14023193.0  14465121.0  14926504.0
# 263  12379549.0  12526968.0  12697723.0  12894316.0  13115131.0  13350356.0
#
#            2014        2015        2016
# 0      103774.0    104341.0    104872.0
# 1    33370794.0  34413603.0  35383128.0
# 2    26941779.0  27884381.0  28842484.0
# 3     2889104.0   2880703.0   2876101.0
# 4       79213.0     78011.0     77297.0
# ..          ...         ...         ...
# 259   1812771.0   1788196.0   1777557.0
# 260  25823485.0  26497889.0  27168210.0
# 261  54545991.0  55386367.0  56203654.0
# 262  15399753.0  15879361.0  16363507.0
# 263  13586681.0  13814629.0  14030390.0
#
# [264 rows x 14 columns]

# %%
# Merge the above data frames to a single data frame
merged_df = pd.concat([CO2_emission_df_2, population_df_2], keys=['CO2_emission', 'population'])
#           names=['Country Name', 'Row ID'])
merged_df
# Out:
#                   Country Name Country Code  \
# CO2_emission 0           Aruba          ABW
#              1     Afghanistan          AFG
#              2          Angola          AGO
#              3         Albania          ALB
#              4         Andorra          AND
# ...                        ...          ...
# population   259        Kosovo          XKX
#              260   Yemen, Rep.          YEM
#              261  South Africa          ZAF
#              262        Zambia          ZMB
#              263      Zimbabwe          ZWE
#
#                                           Indicator Name          2006  \
# CO2_emission 0    CO2 emissions (metric tons per capita)  2.694773e+01
#              1    CO2 emissions (metric tons per capita)  6.242753e-02
#              2    CO2 emissions (metric tons per capita)  1.105019e+00
#              3    CO2 emissions (metric tons per capita)  1.302576e+00
#              4    CO2 emissions (metric tons per capita)  6.746052e+00
# ...                                                  ...           ...
# population   259                       Population, total  1.719536e+06
#              260                       Population, total  2.068765e+07
#              261                       Population, total  4.848946e+07
#              262                       Population, total  1.217351e+07
#              263                       Population, total  1.215549e+07
#
#                           2007          2008          2009          2010  \
# CO2_emission 0    2.789502e+01  2.622955e+01  2.591532e+01  2.467053e+01
#              1    8.389281e-02  1.517209e-01  2.383985e-01  2.899876e-01
#              2    1.203134e+00  1.185000e+00  1.234425e+00  1.244092e+00
#              3    1.322335e+00  1.484311e+00  1.495600e+00  1.578574e+00
#              4    6.519387e+00  6.427810e+00  6.121580e+00  6.122595e+00
# ...                        ...           ...           ...           ...
# population   259  1.733404e+06  1.747383e+06  1.761474e+06  1.775680e+06
#              260  2.128252e+07  2.189215e+07  2.251646e+07  2.315486e+07
#              261  4.911976e+07  4.977947e+07  5.047701e+07  5.121696e+07
#              262  1.250296e+07  1.284853e+07  1.321514e+07  1.360598e+07
#              263  1.225592e+07  1.237955e+07  1.252697e+07  1.269772e+07
#
#                           2011          2012          2013          2014  \
# CO2_emission 0    2.450752e+01  1.315772e+01  8.353561e+00  8.410064e+00
#              1    4.064242e-01  3.451488e-01  2.804546e-01  2.537279e-01
#              2    1.262825e+00  1.361181e+00  1.295075e+00  1.664741e+00
#              3    1.803715e+00  1.697966e+00  1.697279e+00  1.900070e+00
#              4    5.867410e+00  5.916884e+00  5.901775e+00  5.832906e+00
# ...                        ...           ...           ...           ...
# population   259  1.791000e+06  1.807106e+06  1.818117e+06  1.812771e+06
#              260  2.380759e+07  2.447318e+07  2.514711e+07  2.582348e+07
#              261  5.200417e+07  5.283400e+07  5.368924e+07  5.454599e+07
#              262  1.402319e+07  1.446512e+07  1.492650e+07  1.539975e+07
#              263  1.289432e+07  1.311513e+07  1.335036e+07  1.358668e+07
#
#                           2015          2016
# CO2_emission 0    8.610374e+00  8.426911e+00
#              1    2.625557e-01  2.451014e-01
#              2    1.240245e+00  1.202861e+00
#              3    1.602648e+00  1.577163e+00
#              4    5.969786e+00  6.072370e+00
# ...                        ...           ...
# population   259  1.788196e+06  1.777557e+06
#              260  2.649789e+07  2.716821e+07
#              261  5.538637e+07  5.620365e+07
#              262  1.587936e+07  1.636351e+07
#              263  1.381463e+07  1.403039e+07
#
# [528 rows x 14 columns]

# %%
merged_df.to_csv('output.csv')

# %%
# merged_table = merged_df.to_html().replace('\n','')
# merged_table

# %%
# Create a data frame to show the TOTAL carbon emission per country

# Drop string columns in the data frames
CO2_emission_df_value = CO2_emission_df_2.drop(columns=['Country Name', 'Country Code', 'Indicator Name'])
CO2_emission_df_value

population_df_value = population_df_2.drop(columns=['Country Name', 'Country Code', 'Indicator Name'])
population_df_value

# Multiply the data frames
total_emission_value = CO2_emission_df_value * population_df_value.values
total_emission_value
# Out:
#              2006          2007          2008          2009          2010  \
# 0    2.717247e+06  2.823590e+06  2.658575e+06  2.629239e+06  2.508228e+06
# 1    1.650150e+06  2.273540e+06  4.206049e+06  6.769282e+06  8.463436e+06
# 2    2.226602e+07  2.515195e+07  2.570934e+07  2.779219e+07  2.905731e+07
# 3    3.898021e+06  3.927357e+06  4.374731e+06  4.378398e+06  4.598418e+06
# 4    5.463830e+05  5.390490e+05  5.390490e+05  5.170470e+05  5.170470e+05
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN  7.455011e+06  8.192078e+06  8.426766e+06
# 260  2.131627e+07  2.097157e+07  2.233936e+07  2.456523e+07  2.343213e+07
# 261  4.478947e+08  4.665781e+08  4.967722e+08  5.031124e+08  4.698160e+08
# 262  2.291875e+06  1.928842e+06  2.170864e+06  2.508228e+06  2.691578e+06
# 263  1.044728e+07  9.886232e+06  7.770373e+06  5.603176e+06  7.803376e+06
#
#              2011          2012          2013          2014          2015  \
# 0    2.500894e+06  1.349456e+06  8.617450e+05  8.727460e+05  8.984150e+05
# 1    1.224045e+07  1.075531e+07  9.050156e+06  8.467103e+06  9.035488e+06
# 2    3.058645e+07  3.417644e+07  3.369240e+07  4.485108e+07  3.458348e+07
# 3    5.240143e+06  4.924781e+06  4.913780e+06  5.489499e+06  4.616753e+06
# 4    4.913780e+05  4.877110e+05  4.767100e+05  4.620420e+05  4.657090e+05
# ..            ...           ...           ...           ...           ...
# 259  8.368094e+06  7.942722e+06  8.074734e+06  7.260660e+06  8.408431e+06
# 260  2.061221e+07  1.869803e+07  2.549298e+07  2.466791e+07  1.317186e+07
# 261  4.773701e+08  4.646749e+08  4.592221e+08  4.844950e+08  4.639525e+08
# 262  2.922599e+06  3.678001e+06  3.956693e+06  4.503076e+06  4.532412e+06
# 263  9.622208e+06  7.873049e+06  1.177107e+07  1.211577e+07  1.231745e+07
#
#              2016
# 0    8.837470e+05
# 1    8.672455e+06
# 2    3.469349e+07
# 3    4.536079e+06
# 4    4.693760e+05
# ..            ...
# 259  8.943813e+06
# 260  1.060863e+07
# 261  4.766440e+08
# 262  5.141134e+06
# 263  1.098266e+07
#
# [264 rows x 11 columns]

# %%
# Save the total emission dataframe to a CSV
country_names = CO2_emission_df_2[['Country Name', 'Country Code']]
total_emission_df = country_names.join(total_emission_value)

total_emission_df.to_csv('total_emission_by_country.csv',index=False)

# %% [markdown]
# ### Find Goolge Trends for Keywords searches ("Sustainability", "Environment", "Climate Change" and "Clean Energy") by regions. The result will be used for visualization.

# %%
# Find the interest by region for the defined keywords
kw_list = ["Sustainability", "Environment", "Climate Change", "Clean Energy"] 
pytrend.build_payload(kw_list, timeframe='2000-01-01 2017-01-01')
# Interest by Region
interest_by_region = pytrend.interest_by_region()
interest_by_region
# Out:
#                 Sustainability  Environment  Climate Change  Clean Energy
# geoName
# Afghanistan                  0            0               0             0
# Albania                      0            0               0             0
# Algeria                      0            0               0             0
# American Samoa               0            0               0             0
# Andorra                      0            0               0             0
# ...                        ...          ...             ...           ...
# Western Sahara               0            0               0             0
# Yemen                        0            0               0             0
# Zambia                       0            0               0             0
# Zimbabwe                     7           72              21             0
# Åland Islands                0            0               0             0
#
# [250 rows x 4 columns]

# %% [markdown]
# ### Find the popularities of keywords search ("Sustainability", "Environment", "Climate Change" and "Clean Energy") over time. The results will be used for visualization.

# %%
# Save the interest_by_region data frame to a CSV file
interest_by_region.to_csv('pytrend_keywords_by_country.csv')

# %%
# Find keyword rankings from U.S. trend
kw_list = ["Sustainability", "Environment", "Climate Change", "Clean Energy"] 
pytrend.build_payload(kw_list, timeframe='2000-01-01 2017-01-01',geo='US')

# Find the search volume of each keyword over time, and save the result in a data frame
search_trend_US = pytrend.interest_over_time()
search_trend_US
# Out:
#             Sustainability  Environment  Climate Change  Clean Energy  \
# date
# 2004-01-01               5           85               3             1
# 2004-02-01               5           86               8             1
# 2004-03-01               4           95               4             1
# 2004-04-01               5          100               6             1
# 2004-05-01               6           86               5             1
# ...                    ...          ...             ...           ...
# 2016-09-01               9           53              14             2
# 2016-10-01               8           47              17             2
# 2016-11-01               8           49              30             2
# 2016-12-01               7           40              22             2
# 2017-01-01               8           47              23             2
#
#             isPartial
# date
# 2004-01-01      False
# 2004-02-01      False
# 2004-03-01      False
# 2004-04-01      False
# 2004-05-01      False
# ...               ...
# 2016-09-01      False
# 2016-10-01      False
# 2016-11-01      False
# 2016-12-01      False
# 2017-01-01      False
#
# [157 rows x 5 columns]

# %%
search_trend_US_df = search_trend_US.groupby(search_trend_US.index.map(lambda x: x.year)).sum()
search_trend_US_df_2 = search_trend_US_df[['Sustainability','Environment','Climate Change','Clean Energy']]
search_trend_US_df_2
# Out:
#       Sustainability  Environment  Climate Change  Clean Energy
# date
# 2004              53          981              55            13
# 2005              53          853              52            18
# 2006              55          690              65            21
# 2007              77          681             122            25
# 2008             100          681             122            33
# 2009             113          668             157            43
# 2010             117          629             114            34
# 2011             112          551              91            30
# 2012             106          521              93            29
# 2013              98          524             103            25
# 2014              98          535             149            24
# 2015              98          567             184            24
# 2016              92          529             190            25
# 2017               8           47              23             2

# %%
# Save to a CSV
search_trend_US_df_2.to_csv('keyword_search_volume_US.csv')

# %%
# # Calculate the average for each column in the data frame
# avg_popularity = []
# for item in kw_list:
#     avg_popularity.append(search_trend_US[item].mean())

# avg_popularity

# %%
# # Store avg info in a dictionary
# avg_popularity_dict = {
#     'Sustainability': avg_popularity[0],
#     'Environment': avg_popularity[1],
#     'Climate Change': avg_popularity[2],
#     'Clean Energy': avg_popularity[3]
# }

# # Convert the dictionary to a data frame
# avg_popularity_US = pd.DataFrame(data=avg_popularity_dict, index=[0])
# avg_popularity_US

# %% [markdown]
# ### Find Google query trends for "Sustainability", "Environment", "Climate Change" and "Clean Energy". The result will be converted to HTML table strings for final web applications.

# %%
pytrend.build_payload(kw_list = ["Sustainability", "Environment", "Climate Change", "Clean Energy"] )
# Related Queries, returns a dictionary of dataframes
related_queries = pytrend.related_queries()
# related_queries.values()
print(related_queries)
# Out:
# {'Sustainability': {'top':                            query  value
# 0   environmental sustainability    100
# 1                  environmental    100
# 2         what is sustainability     87
# 3                    sustainable     85
# 4      sustainability definition     80
# 5            sustainability jobs     56
# 6          sustainability report     50
# 7          energy sustainability     43
# 8        business sustainability     40
# 9      sustainability management     34
# 10         social sustainability     33
# 11    sustainability environment     32
# 12          water sustainability     32
# 13                   environment     31
# 14         global sustainability     30
# 15      what does sustainability     30
# 16        sustainability science     30
# 17           food sustainability     29
# 18  definition of sustainability     28
# 19         google sustainability     27
# 20      corporate sustainability     24
# 21      office of sustainability     20
# 22       sustainability examples     19
# 23         define sustainability     18
# 24           sustainability plan     17, 'rising':                                                 query  value
# 0                      pokemon go sustainability week  12500
# 1                              seaside sustainability   4100
# 2                         silver falls sustainability   2750
# 3                          walmart sustainability hub   2700
# 4               women in cleantech and sustainability   2700
# 5                 local journalism sustainability act   2000
# 6                   morningstar sustainability rating    750
# 7                                 zara sustainability    650
# 8                          synonym for sustainability    600
# 9                                  esg sustainability    450
# 10                         amazon sustainability jobs    300
# 11                              adidas sustainability    300
# 12                              sustainability arvada    300
# 13                             sustainability defined    300
# 14  how does biodiversity contribute to the sustai...    250
# 15                               what is biodiversity    250
# 16                                sustainability week    250
# 17               sustainability merit badge worksheet    200
# 18                             tragedy of the commons    190
# 19                               sustainability goals    150
# 20                            sustainability examples     70
# 21                           what does sustainability     60
# 22                             jobs in sustainability     50
# 23                             what is sustainability     40
# 24                              environmental science     40}, 'Environment': {'top':                             query  value
# 0                 the environment    100
# 1                work environment     17
# 2           environment variables     11
# 3          environment definition     11
# 4              living environment      8
# 5                         hostile      6
# 6             hostile environment      6
# 7             natural environment      6
# 8        hostile work environment      5
# 9         development environment      5
# 10                         python      5
# 11             social environment      5
# 12                           java      4
# 13       set environment variable      4
# 14             school environment      4
# 15     living environment regents      3
# 16            environment control      3
# 17             define environment      3
# 18  human environment interaction      2
# 19            environment synonym      2
# 20           external environment      2
# 21       java runtime environment      2
# 22                      ecosystem      2
# 23         production environment      2
# 24             environment canada      2, 'rising':                                                 query  value
# 0                            conda create environment   7350
# 1                        conda create new environment   4800
# 2                         anaconda create environment   3150
# 3       procurement integrated enterprise environment   3100
# 4                june 2016 living environment regents   3100
# 5      all things that occur in a certain environment   1600
# 6   there is insufficient memory for the java runt...   1350
# 7   i am going to create an environment that is so...   1100
# 8                    windows 10 environment variables    850
# 9                    docker run environment variables    700
# 10                     new visions living environment    700
# 11                       docker environment variables    600
# 12                         python virtual environment    600
# 13             is almond milk bad for the environment    550
# 14                    almond milk bad for environment    550
# 15                             toxic work environment    300
# 16                                             python    190
# 17                    python get environment variable    190
# 18                         inclusive work environment    190
# 19      tns_admin environment variable is not defined    140
# 20                       python environment variables    140
# 21                      jenkins environment variables    120
# 22                                environment synonym    110
# 23                powershell set environment variable    110
# 24                            synonym for environment    100}, 'Climate Change': {'top':                                 query  value
# 0                   climate change is    100
# 1              what is climate change     48
# 2               global climate change     48
# 3                     what is climate     47
# 4                      global warming     27
# 5           climate change definition     21
# 6                  climate definition     20
# 7                climate change trump     19
# 8            what is a climate change     18
# 9              climate change effects     17
# 10                              earth     14
# 11              climate change causes     13
# 12                climate change news     13
# 13               climate change cause     13
# 14          effects of climate change     11
# 15      what is global climate change     10
# 16  global warming and climate change      9
# 17               climate change facts      9
# 18             climate change science      9
# 19          climate change scientists      8
# 20           causes of climate change      8
# 21             is climate change real      8
# 22            cause of climate change      8
# 23       definition of climate change      7
# 24         what causes climate change      7, 'rising':                                                 query   value
# 0                                 climate change 2019  103950
# 1                                      greta thunberg   46450
# 2                          coronavirus climate change   39300
# 3                trump paris climate change agreement   19650
# 4                                      green new deal   14800
# 5                            joe biden climate change   12300
# 6                          trump climate change tweet   12050
# 7                          climate change report 2018   11900
# 8                         scott pruitt climate change   11400
# 9                        climate change is real shirt    9900
# 10                               bezos climate change    9050
# 11                                   before the flood    8850
# 12                            biden on climate change    8550
# 13               does trump believe in climate change    6300
# 14                     climate change and coronavirus    6250
# 15                             pitbull climate change    6150
# 16                           climate change town hall    5950
# 17               trump executive order climate change    5400
# 18                      ted cruz climate change tweet    5200
# 19                               biden climate change    4600
# 20                               greta climate change    3800
# 21                       climate change protest signs    3300
# 22                 climate change strike september 20    3200
# 23                        joe biden on climate change    3050
# 24  climate change is evidenced by which of the fo...    2750}, 'Clean Energy': {'top':                       query  value
# 0      what is clean energy    100
# 1    clean renewable energy     83
# 2          renewable energy     81
# 3        clean energy stock     72
# 4       clean energy stocks     62
# 5         clean energy jobs     59
# 6        clean energy fuels     59
# 7          clean energy etf     44
# 8            nuclear energy     42
# 9       clean choice energy     39
# 10        clean energy fuel     38
# 11               clean coal     37
# 12   clean energy companies     35
# 13  california clean energy     31
# 14        clean energy fund     30
# 15     clean energy company     30
# 16      global clean energy     29
# 17          nj clean energy     27
# 18     clean energy sources     27
# 19  is nuclear energy clean     26
# 20        apex clean energy     25
# 21  clean energy definition     23
# 22       clean energy drink     23
# 23                     apex     23
# 24     is coal clean energy     22, 'rising':                                                 query   value
# 0                                  biden clean energy  107500
# 1                               san jose clean energy   46750
# 2                                                icln   45450
# 3                        affordable clean energy rule   40650
# 4                         ishares global clean energy   40000
# 5                         clean choice energy reviews   35200
# 6                                  aries clean energy   33600
# 7                               carnegie clean energy   28200
# 8                             biden clean energy plan   25550
# 9                                  scout clean energy   25100
# 10                    ishares global clean energy etf   22900
# 11                       valley clean energy alliance   22600
# 12                                         plug stock   20200
# 13                          clean energy jobs near me   19200
# 14                clean energy companies to invest in   18400
# 15                   new england clean energy connect   14950
# 16                     clean energy standard new york   13700
# 17                         vanguard clean energy fund   13650
# 18                              alps clean energy etf   13150
# 19                        carnegie clean energy stock   13000
# 20                invesco wilderhill clean energy etf   11050
# 21                    california clean energy program   10950
# 22                happening a clean energy revolution   10800
# 23  san jose clean energy electric generation charges    6950
# 24                             my clean choice energy    6800}}

# %%
# # build list of keywords
# kw_list = ["Sustainability", "Environment", "Climate Change", "Clean Energy"] 
# # build the payload
# pytrend.build_payload(kw_list, timeframe='2000-01-01 2017-01-01')
# interest_over_time = pytrend.interest_over_time()
# interest_over_time_html = interest_over_time.to_html().replace('\n','')
# # print(interest_over_time_html)

# %% [markdown]
# ### Grab world countries capital cities and their locations

# %%
# Name the capitals CSV file
capitals_file = pathlib.Path('country-capitals.csv')

# Read and display the CO2 Emission CSV with Pandas
capitals_df = pd.read_csv(capitals_file)
capitals_df = capitals_df.drop(columns=['CountryCode','ContinentName','CapitalName'])
# capitals_df = capitals_df.rename(columns = {'CountryName':'Country Name'})

# %%
CO2_emission_df_3 = CO2_emission_df_2.rename(columns = {'Country Name':'CountryName'})
CO2_emission_df_3['avgCarbonEmission'] = round(CO2_emission_df_3.mean(axis=1),2)
CO2_emission_df_3
# Out:
#       CountryName Country Code                          Indicator Name  \
# 0           Aruba          ABW  CO2 emissions (metric tons per capita)
# 1     Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2          Angola          AGO  CO2 emissions (metric tons per capita)
# 3         Albania          ALB  CO2 emissions (metric tons per capita)
# 4         Andorra          AND  CO2 emissions (metric tons per capita)
# ..            ...          ...                                     ...
# 259        Kosovo          XKX  CO2 emissions (metric tons per capita)
# 260   Yemen, Rep.          YEM  CO2 emissions (metric tons per capita)
# 261  South Africa          ZAF  CO2 emissions (metric tons per capita)
# 262        Zambia          ZMB  CO2 emissions (metric tons per capita)
# 263      Zimbabwe          ZWE  CO2 emissions (metric tons per capita)
#
#           2006       2007       2008       2009       2010       2011  \
# 0    26.947726  27.895023  26.229553  25.915322  24.670529  24.507516
# 1     0.062428   0.083893   0.151721   0.238399   0.289988   0.406424
# 2     1.105019   1.203134   1.185000   1.234425   1.244092   1.262825
# 3     1.302576   1.322335   1.484311   1.495600   1.578574   1.803715
# 4     6.746052   6.519387   6.427810   6.121580   6.122595   5.867410
# ..         ...        ...        ...        ...        ...        ...
# 259        NaN        NaN   4.266386   4.650695   4.745656   4.672303
# 260   1.030386   0.985390   1.020428   1.090990   1.011975   0.865783
# 261   9.236950   9.498786   9.979458   9.967159   9.173055   9.179457
# 262   0.188267   0.154271   0.168958   0.189800   0.197823   0.208412
# 263   0.859470   0.806649   0.627678   0.447289   0.614549   0.746236
#
#           2012      2013      2014      2015      2016  avgCarbonEmission
# 0    13.157722  8.353561  8.410064  8.610374  8.426911              18.47
# 1     0.345149  0.280455  0.253728  0.262556  0.245101               0.24
# 2     1.361181  1.295075  1.664741  1.240245  1.202861               1.27
# 3     1.697966  1.697279  1.900070  1.602648  1.577163               1.59
# 4     5.916884  5.901775  5.832906  5.969786  6.072370               6.14
# ..         ...       ...       ...       ...       ...                ...
# 259   4.395272  4.441262  4.005283  4.702186  5.031520               4.55
# 260   0.764021  1.013754  0.955251  0.497091  0.390480               0.88
# 261   8.794997  8.553336  8.882322  8.376655  8.480658               9.10
# 262   0.254267  0.265078  0.292412  0.285428  0.314183               0.23
# 263   0.600303  0.881705  0.891739  0.891624  0.782777               0.74
#
# [264 rows x 15 columns]

# %%
population_df_3 = population_df_2.rename(columns = {'Country Name':'CountryName'})
population_df_3['avgPopulation'] = round(population_df_3.mean(axis=1),0)
population_df_3
# Out:
#       CountryName Country Code     Indicator Name        2006        2007  \
# 0           Aruba          ABW  Population, total    100834.0    101222.0
# 1     Afghanistan          AFG  Population, total  26433049.0  27100536.0
# 2          Angola          AGO  Population, total  20149901.0  20905363.0
# 3         Albania          ALB  Population, total   2992547.0   2970017.0
# 4         Andorra          AND  Population, total     80993.0     82684.0
# ..            ...          ...                ...         ...         ...
# 259        Kosovo          XKX  Population, total   1719536.0   1733404.0
# 260   Yemen, Rep.          YEM  Population, total  20687646.0  21282515.0
# 261  South Africa          ZAF  Population, total  48489459.0  49119759.0
# 262        Zambia          ZMB  Population, total  12173514.0  12502958.0
# 263      Zimbabwe          ZWE  Population, total  12155491.0  12255922.0
#
#            2008        2009        2010        2011        2012        2013  \
# 0      101358.0    101455.0    101669.0    102046.0    102560.0    103159.0
# 1    27722276.0  28394813.0  29185507.0  30117413.0  31161376.0  32269589.0
# 2    21695634.0  22514281.0  23356246.0  24220661.0  25107931.0  26015780.0
# 3     2947314.0   2927519.0   2913021.0   2905195.0   2900401.0   2895092.0
# 4       83862.0     84463.0     84449.0     83747.0     82427.0     80774.0
# ..          ...         ...         ...         ...         ...         ...
# 259   1747383.0   1761474.0   1775680.0   1791000.0   1807106.0   1818117.0
# 260  21892146.0  22516460.0  23154855.0  23807588.0  24473178.0  25147109.0
# 261  49779471.0  50477011.0  51216964.0  52004172.0  52834005.0  53689236.0
# 262  12848530.0  13215139.0  13605984.0  14023193.0  14465121.0  14926504.0
# 263  12379549.0  12526968.0  12697723.0  12894316.0  13115131.0  13350356.0
#
#            2014        2015        2016  avgPopulation
# 0      103774.0    104341.0    104872.0       102481.0
# 1    33370794.0  34413603.0  35383128.0     30504735.0
# 2    26941779.0  27884381.0  28842484.0     24330404.0
# 3     2889104.0   2880703.0   2876101.0      2917910.0
# 4       79213.0     78011.0     77297.0        81629.0
# ..          ...         ...         ...            ...
# 259   1812771.0   1788196.0   1777557.0      1775657.0
# 260  25823485.0  26497889.0  27168210.0     23859189.0
# 261  54545991.0  55386367.0  56203654.0     52158735.0
# 262  15399753.0  15879361.0  16363507.0     14127597.0
# 263  13586681.0  13814629.0  14030390.0     12982469.0
#
# [264 rows x 15 columns]

# %%
loc_emission_df = capitals_df.merge(CO2_emission_df_3, on='CountryName')
loc_emission_df = loc_emission_df.drop(columns=['Country Code','Indicator Name','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016'])
loc_emission_pop_df = loc_emission_df.merge(population_df_3, on='CountryName')
loc_emission_pop_df = loc_emission_pop_df.drop(columns=['Country Code','Indicator Name','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016'])
# loc_emission_df = loc_emission_df.set_index('Country Name')
# loc_emission_df = loc_emission_df.reset_index(drop=True)
# loc_emission_df = loc_emission_df.transpose()
# loc_emission_df = loc_emission_df.rename(columns = {'2014':'CarbonEmission'}).dropna()
loc_emission_pop_df
# Out:
#               CountryName  CapitalLatitude  CapitalLongitude  \
# 0                   Nauru        -0.547700        166.920867
# 1             Afghanistan        34.516667         69.183333
# 2                 Albania        41.316667         19.816667
# 3                 Algeria        36.750000          3.050000
# 4          American Samoa       -14.266667       -170.700000
# ..                    ...              ...               ...
# 185               Vietnam        21.033333        105.850000
# 186                Zambia       -15.416667         28.283333
# 187              Zimbabwe       -17.816667         31.033333
# 188  Hong Kong SAR, China        22.319300        114.169400
# 189      Macao SAR, China        22.198700        113.543900
#
#      avgCarbonEmission  avgPopulation
# 0                 4.12        10731.0
# 1                 0.24     30504735.0
# 2                 1.59      2917910.0
# 3                 3.43     36839863.0
# 4                  NaN        56564.0
# ..                 ...            ...
# 185               1.61     88981669.0
# 186               0.23     14127597.0
# 187               0.74     12982469.0
# 188               6.08      7089655.0
# 189               2.81       552322.0
#
# [190 rows x 5 columns]

# %%
loc_emission_pop_df = loc_emission_pop_df.rename(columns = {'avgCarbonEmission':'CarbonEmission', 'avgPopulation':'Population'}).dropna()
loc_emission_pop_df['Population'] = loc_emission_pop_df['Population'].astype(int)
loc_emission_pop_df
# Out:
#               CountryName  CapitalLatitude  CapitalLongitude  CarbonEmission  \
# 0                   Nauru        -0.547700        166.920867            4.12
# 1             Afghanistan        34.516667         69.183333            0.24
# 2                 Albania        41.316667         19.816667            1.59
# 3                 Algeria        36.750000          3.050000            3.43
# 5                 Andorra        42.500000          1.516667            6.14
# ..                    ...              ...               ...             ...
# 185               Vietnam        21.033333        105.850000            1.61
# 186                Zambia       -15.416667         28.283333            0.23
# 187              Zimbabwe       -17.816667         31.033333            0.74
# 188  Hong Kong SAR, China        22.319300        114.169400            6.08
# 189      Macao SAR, China        22.198700        113.543900            2.81
#
#      Population
# 0         10731
# 1      30504735
# 2       2917910
# 3      36839863
# 5         81629
# ..          ...
# 185    88981669
# 186    14127597
# 187    12982469
# 188     7089655
# 189      552322
#
# [183 rows x 5 columns]

# %%
# loc_emission_df.to_json('emission_by_location.json')
loc_emission_pop_df.to_json('emission_population_location_copy.json',orient='records')

# %%
# loc_emission_json = loc_emission_df.to_json()
# loc_emission_json

# loc_emission_json = json.dumps(loc_emission_json, sort_keys=True)
# loc_emission_json
# emission_by_loc = open('emission_by_location.json','w')
# emission_by_loc.write(loc_emission_json)

# %%
total_emission_df['average'] = total_emission_df.mean(axis=1)

# %%
# total_emission_df.sort_values(by=['Country Name'],ascending=True)
# total_emission_df['Country Name'].unique()
# country_filter = ['High income', 'Low income', 'Middle income', 'Upper middle income','Lower middle income' ]

emissions_by_income = total_emission_df.loc[(total_emission_df['Country Name']=='High income')|(total_emission_df['Country Name']=='Low income')|(total_emission_df['Country Name']=='Middle income')|(total_emission_df['Country Name']=='Upper middle income')|(total_emission_df['Country Name']=='Lower middle income')]
emissions_by_income = emissions_by_income.rename(columns={'Country Name':'IncomeLevel', 'average':'avgEmission'})
emissions_by_income
# Out:
#              IncomeLevel Country Code          2006          2007  \
# 93           High income          HIC  1.380044e+10  1.387558e+10
# 134           Low income          LIC  2.017976e+08  2.076683e+08
# 137  Lower middle income          LMC  2.738802e+09  2.888210e+09
# 154        Middle income          MIC  1.500589e+10  1.541615e+10
# 247  Upper middle income          UMC  1.226710e+10  1.252791e+10
#
#              2008          2009          2010          2011          2012  \
# 93   1.368713e+10  1.295561e+10  1.338530e+10  1.314847e+10  1.306566e+10
# 134  2.220689e+08  2.063519e+08  2.053079e+08  1.901356e+08  1.779063e+08
# 137  3.078791e+09  3.200253e+09  3.316893e+09  3.499128e+09  3.714345e+09
# 154  1.675575e+10  1.673773e+10  1.831857e+10  1.973064e+10  2.041699e+10
# 247  1.367677e+10  1.353747e+10  1.500168e+10  1.623152e+10  1.670265e+10
#
#              2013          2014          2015          2016   avgEmission  \
# 93   1.307138e+10  1.298531e+10  1.290927e+10  1.266931e+10  1.221428e+10
# 134  1.707667e+08  1.789423e+08  1.645656e+08  1.682030e+08  1.756963e+08
# 137  3.736262e+09  3.982718e+09  4.101459e+09  4.229048e+09  3.229587e+09
# 154  2.058268e+10  2.091511e+10  2.094005e+10  2.094755e+10  1.726717e+10
# 247  1.684643e+10  1.693239e+10  1.683859e+10  1.671849e+10  1.403757e+10
#
#       avgEmission
# 93   1.323213e+10
# 134  1.903376e+08
# 137  3.498719e+09
# 154  1.870610e+10
# 247  1.520736e+10

# %%
# Save to a CSV
emissions_by_income.to_csv('emissions_by_income_level_copy.csv')
